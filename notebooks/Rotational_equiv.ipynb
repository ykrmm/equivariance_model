# %% [markdown]
# # Rotation Equivariance for Semi supervised semantic segmentation

# %%
# %matplotlib inline
import argparse
import os
import random
import torch
import torch.nn as nn
import torch.nn.parallel
import torch.backends.cudnn as cudnn
import torch.optim as optim
import torchvision
from torchvision import models
import torch.utils.data as tud
import torchvision.datasets as dset
import torchvision.transforms as transforms
import torchvision.transforms.functional as TF
import torchvision.utils as vutils
from torch.utils.data import DataLoader, Dataset
from torch.utils.data.dataset import random_split
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from IPython.display import HTML
from tqdm import tqdm
from PIL import Image
from collections import Counter
from sklearn.metrics import jaccard_score
import pickle
import my_datasets as mdset
import eval_train as ev
from utils import *

# %% [markdown]
# ## Parameters

# %%
#MODEL SAVE AND LOAD 
dataroot_voc = '/data/voc2012'
dataroot_sbd = '/data/sbd'
model_name = 'fcn_voc_sbd30_semisup_g05_no_pretrain_CE' # Model name for save during semisup training
SAVE_DIR = '/data/model'
file_base = None # Base model 
fcn= True
pretrained=False
save_all_ep = True # A save for each epoch 
save = os.path.join(SAVE_DIR,model_name)
# MODEL PARAMETERS 
desactivate_bn = False # Desactive BatchNorm for fine tune models. 
# TRAIN PARAMETERS
batch_size = 2
gamma = 0.5
learning_rate = 10e-4
moment = 0.9
wd = 2e-4
n_epochs = 25 # N_epoch for multi_task/semi sup training
n_epochs_supervised = 20 # Train in fully supervised for n_epoch_supervised
angle_max = 30

# LOSS 

#criterion_unsupervised = nn.L1Loss(reduction='mean')
#criterion_unsupervised = nn.KLDivLoss(reduction = 'batchmean', log_target = False)
criterion_unsupervised = nn.CrossEntropyLoss(ignore_index=21)
criterion_supervised = nn.CrossEntropyLoss(ignore_index=21) # On ignore la classe border.
Loss = 'CE' # Loss = 'KL' or 'CE' or None for L1,MSE…

# DATASET AND DATA AUG 
rotate = False # random rotation during training
split = True # split the supervised dataset
rate = 0.3 # percent of data of VOC + SBD we use for supervised dataset
fully_supervised = False # Use the same dataloader for equivariance loss and supervised loss

# BEFORE TRAIN IN SEMISUP/MULTITASK
pretrain_model = False  # Pretrain the model in a fully supervised way before appli equiv loss
eval_before_semisup = False # Eval the loaded model before training with equiv_loss

# %% [markdown]
# ## DATASETS

# %%
train_dataset_VOC = mdset.VOCSegmentation(dataroot_voc,year='2012', image_set='train', download=True,rotate=rotate)
val_dataset_VOC = mdset.VOCSegmentation(dataroot_voc,year='2012', image_set='val', download=True)
train_dataset_SBD = mdset.SBDataset(dataroot_sbd, image_set='train_noval',mode='segmentation',rotate=rotate)
# Out:
# Using downloaded and verified file: /data/voc2012/VOCtrainval_11-May-2012.tar
# Using downloaded and verified file: /data/voc2012/VOCtrainval_11-May-2012.tar

# %% [markdown]
# ### Concatene Dataset

# %%
train_dataset_unsup = tud.ConcatDataset([train_dataset_VOC,train_dataset_SBD])

# %% [markdown]
# ### Split dataset

# %%
if split:
    train_dataset_sup = split_dataset(train_dataset_unsup,rate)

# %%
if fully_supervised : 
    train_dataset_unsup = train_dataset_sup

dataloader_train_VOC = torch.utils.data.DataLoader(train_dataset_VOC, batch_size=batch_size,\
                                                       shuffle=True,drop_last=True)
dataloader_train_sup = torch.utils.data.DataLoader(train_dataset_sup, batch_size=batch_size,\
                                                       shuffle=True,drop_last=True)
dataloader_train_equiv = torch.utils.data.DataLoader(train_dataset_unsup,batch_size=batch_size,\
                                                     shuffle=True,drop_last=True)

dataloader_val = torch.utils.data.DataLoader(val_dataset_VOC, batch_size=batch_size)
# Decide which device we want to run on
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print("device :",device)
# Out:
# device : cuda:0

# %%
print("Taille dataset train supervised :",len(train_dataset_sup))
print("Taille dataset train unsupervised :",len(train_dataset_unsup))
print("Taille dataset val VOC :",len(val_dataset_VOC))
# Out:
# Taille dataset train supervised : 2126
# Taille dataset train unsupervised : 7087
# Taille dataset val VOC : 1449

# %% [markdown]
# ## FCN Pytorch

# %%
def load_model(file=None,fcn=False,pretrained=False):
    if file is None:
        if fcn is False:
            model = torchvision.models.segmentation.deeplabv3_resnet101(pretrained=pretrained)
        else:
            model = torchvision.models.segmentation.fcn_resnet101(pretrained=pretrained)
    else:
        model = torch.load(os.path.join(SAVE_DIR,file))
    return model

# %%
model = load_model(file=file_base,fcn=fcn,pretrained=pretrained)

# %%
model.to(device)
# Out:
# FCN(
#   (backbone): IntermediateLayerGetter(
#     (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer2): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer3): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (4): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (5): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (6): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (7): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (8): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (9): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (10): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (11): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (12): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (13): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (14): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (15): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (16): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (17): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (18): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (19): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (20): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (21): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (22): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer4): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(4, 4), dilation=(4, 4), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(4, 4), dilation=(4, 4), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#   )
#   (classifier): FCNHead(
#     (0): Conv2d(2048, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.1, inplace=False)
#     (4): Conv2d(512, 21, kernel_size=(1, 1), stride=(1, 1))
#   )
# )

# %% [markdown]
# ## Training

# %%
iou_train = []
iou_test = []
combine_loss_train = []
combine_loss_test = []
loss_train_unsup = []
loss_train_sup = []
loss_test = []
loss_test_unsup = []
pix_accuracy_train = []
pix_accuracy_test = []
accuracy_test = []
accuracy_train = []
#
all_combine_loss_train = []
all_loss_train_sup = []
all_loss_train_unsup = []
all_iou_train= []
all_pix_accuracy =  []

# %%
optimizer = torch.optim.SGD(model.parameters(),lr=learning_rate,momentum=moment, weight_decay=wd)

# %% [markdown]
# ### Pretrain fully supervised

# %%
## pretrain the model in fully supervised
if pretrain_model:
    torch.autograd.set_detect_anomaly(True)
    for ep in range(n_epochs_supervised):
        
        print("EPOCH",ep)
        model.train()
        if desactivate_bn : 
            model.apply(deactivate_batchnorm) # Disable BN 
        for i,(x,mask) in enumerate(dataloader_train_sup):
            x = x.to(device)
            mask = mask.to(device)  
            pred = model(x)
            pred = pred["out"]
            loss = criterion_supervised(pred,mask)
            all_loss_train_sup.append(loss.item())
            optimizer.zero_grad()
            loss.backward()
            all_iou_train.append(inter_over_union(pred.argmax(dim=1).detach().cpu(),mask.detach().cpu()))
            optimizer.step()        

        #lr_scheduler.step()
        m_iou = np.array(all_iou_train).mean()
        m_loss = np.array(all_loss_train_sup).mean()
        loss_train_sup.append(m_loss)
        iou_train.append(m_iou)
        all_loss_train_sup = []
        all_iou_train = []
        print("EP:",ep," loss train:",m_loss," iou train:",m_iou)

        #Eval model

        model.eval()
        state = ev.eval_model(model,dataloader_val,device=device,num_classes=21)
        iou = state.metrics['mean IoU']
        acc = state.metrics['accuracy']
        loss = state.metrics['CE Loss'] 
        loss_test.append(loss)
        iou_test.append(iou)
        accuracy_test.append(acc)
        print('EP:',ep,'iou:',state.metrics['mean IoU'],\
              'Accuracy:',state.metrics['accuracy'],'Loss CE',state.metrics['CE Loss'])

        torch.save(model,save)
        ## Save model
        if save_all_ep:
            save_model = model_name+'_pretrain_sup'+'_ep'+str(ep)+'.pt'
            save = os.path.join(SAVE_DIR,save_model)
            torch.save(model,save)
        else:
            save_model = model_name+'_pretrain_sup'+'.pt'
            save = os.path.join(SAVE_DIR,save_model)
            torch.save(model,save)

# %%
if eval_before_semisup:
    model.eval()
    print("EVAL ON TRAIN VOC 2012:")
    m_pix_acc, m_loss_equiv = eval_accuracy_equiv(model,dataloader_train_VOC,criterion=criterion_unsupervised,\
                            nclass=21,device=device,Loss=Loss,plot=False,angle_max=30,random_angle=False) 
    d_iou = ev.eval_model_all_angle(model,train=True,batch_size=batch_size,device=device,num_classes=21)
    print("EVAL ON VAL VOC 2012:")
    m_pix_acc, m_loss_equiv = eval_accuracy_equiv(model,dataloader_val,criterion=criterion_unsupervised,\
                            nclass=21,device=device,Loss=Loss,plot=False,angle_max=30,random_angle=False) 
    d_iou = ev.eval_model_all_angle(model,train=False,batch_size=batch_size,device=device,num_classes=21)

# %%
learning_rate = 2*learning_rate

# %% [markdown]
# ### Semi sup training

# %%
torch.autograd.set_detect_anomaly(True)
#torch.backends.cudnn.benchmark=True
for ep in range(n_epochs):
    #dataloader_train_sup = torch.utils.data.DataLoader(train_dataset_sup, batch_size=batch_size,\
                                                      # shuffle=True,drop_last=True)
    dataloader_train_equiv = torch.utils.data.DataLoader(train_dataset_unsup,batch_size=batch_size,\
                                                     shuffle=True,drop_last=True)
    print("EPOCH",ep)
    model.train()
    if desactivate_bn : 
        model.apply(deactivate_batchnorm) # Disable BN 
    for batch_sup,batch_unsup in zip(dataloader_train_sup,dataloader_train_equiv):
        optimizer.zero_grad()
        if random.random() > 0.5: # I use this to rotate the image on the left and on the right during training.
            angle = np.random.randint(0,angle_max)
        else:
            angle = np.random.randint(360-angle_max,360)
        x_unsup,_ = batch_unsup
        loss_equiv,acc = compute_transformations_batch(x_unsup,model,angle,reshape=False,\
                                                     criterion=criterion_unsupervised,Loss = Loss,\
                                                       device=device)
        x,mask = batch_sup
        x = x.to(device)
        mask = mask.to(device)
        pred = model(x)["out"]
        loss_equiv = loss_equiv.to(device) # otherwise bug in combining the loss 
        loss_sup = criterion_supervised(pred,mask)
        loss = gamma*loss_sup + (1-gamma)*loss_equiv # combine loss              
        loss.backward()
        optimizer.step()
        
        # append for plot
        all_pix_accuracy.append(acc) # accuracy between the original mask and the transform mask put back in place
        all_loss_train_unsup.append(loss_equiv.item())
        all_loss_train_sup.append(loss_sup.item())
        all_combine_loss_train.append(loss.item())
            
    #lr_scheduler.step()
    #
    # Eval IoU Train 
    state = ev.eval_model(model,dataloader_val,device=device,num_classes=21)
    iou = state.metrics['mean IoU']
    iou_train.append(iou)
    m_loss_combine = np.array(all_combine_loss_train).mean()
    m_acc = np.array(all_pix_accuracy).mean()
    combine_loss_train.append(m_loss_combine)
    pix_accuracy_train.append(m_acc)
    loss_train_sup.append(np.array(all_loss_train_sup).mean())
    loss_train_unsup.append(np.array(all_loss_train_unsup).mean())

    all_pix_accuracy = []
    all_loss_train_unsup = []
    all_loss_train_sup = []
    all_combine_loss_train = []
    print("loss sup :",loss_sup.item(),"loss unsup :",loss_equiv.item(),"loss :",loss.item(),"iou train :",iou) 
    print("EP:",ep," combine loss train:",m_loss_combine," pixel accuracy between masks ",m_acc)

    ## Evaluate the  model
    model.eval()
    state = ev.eval_model(model,dataloader_val,device=device,num_classes=21)
    iou = state.metrics['mean IoU']
    acc = state.metrics['accuracy']
    loss = state.metrics['CE Loss']
    print('EP:',ep,'iou:',state.metrics['mean IoU'],\
          'Accuracy:',state.metrics['accuracy'],'Loss CE',state.metrics['CE Loss'])
    loss_test.append(loss)
    iou_test.append(iou)
    accuracy_test.append(acc)
    if ep%3==0: # Eval loss equiv and equivariance accuracy for the validation dataset
        m_pix_acc, m_loss_equiv = eval_accuracy_equiv(model,dataloader_val,criterion=criterion_unsupervised,\
                        nclass=21,device=device,Loss=Loss,plot=False,angle_max=30,random_angle=False)
        loss_test_unsup.append(m_loss_equiv)
        pix_accuracy_test.append(m_pix_acc)    
    if ep%5==0: # Eval IoU on rotated input images
        print('VOC Dataset Train')
        d_iou = ev.eval_model_all_angle(model,train=True,batch_size=batch_size,device=device,num_classes=21)
        print('VOC Dataset Val')
        d_iou = ev.eval_model_all_angle(model,train=False,batch_size=batch_size,device=device,num_classes=21)
    ## Save model
    if save_all_ep:
        save_model = model_name+'_ep'+str(ep)+'.pt'
        save = os.path.join(SAVE_DIR,save_model)
        torch.save(model,save)
    else:
        save_model = model_name+'.pt'
        save = os.path.join(SAVE_DIR,save_model)
        torch.save(model,save)
# Out:
# EPOCH 0
# /workspace/utils.py:143: RuntimeWarning: invalid value encountered in true_divide
#   acc_cls = np.diag(hist) / hist.sum(axis=1)
# /workspace/utils.py:145: RuntimeWarning: invalid value encountered in true_divide
#   iu = np.diag(hist) / (hist.sum(axis=1) + hist.sum(axis=0) - np.diag(hist))
# loss sup : 0.3451927900314331 loss unsup : 0.35268694162368774 loss : 0.3489398658275604 iou train : 0.37717149273840633
# EP: 0  combine loss train: 0.6947792082155861  pixel accuracy between masks  0.9399272094994512
# EP: 0 iou: 0.37717149273840633 Accuracy: 0.8619365400949849 Loss CE 0.442701490440395
# Mean Pixel Accuracy between masks : 0.9332793868598246 Loss Validation : 0.2623709
# VOC Dataset Train
# Using downloaded and verified file: /data/voc2012/VOCtrainval_11-May-2012.tar
# Using downloaded and verified file: /data/voc2012/VOCtrainval_11-May-2012.tar
# Using downloaded and verified file: /data/voc2012/VOCtrainval_11-May-2012.tar
# Using downloaded and verified file: /data/voc2012/VOCtrainval_11-May-2012.tar
# Using downloaded and verified file: /data/voc2012/VOCtrainval_11-May-2012.tar
# Using downloaded and verified file: /data/voc2012/VOCtrainval_11-May-2012.tar
# Using downloaded and verified file: /data/voc2012/VOCtrainval_11-May-2012.tar
# Scores for datasets rotate by 0 degrees:
#    mIoU 0.3854666950011254 Accuracy 0.8623724769214602 CE Loss 0.44463024329129464
# Scores for datasets rotate by 10 degrees:
#    mIoU 0.3334670453108583 Accuracy 0.8555739751067029 CE Loss 0.4917773331255942
# Scores for datasets rotate by 20 degrees:
#    mIoU 0.3012158636265196 Accuracy 0.8507163971812656 CE Loss 0.5200593422518157
# Scores for datasets rotate by 30 degrees:
#    mIoU 0.29053065912808673 Accuracy 0.8500862919132149 CE Loss 0.5235865737611805
# Scores for datasets rotate by 330 degrees:
#    mIoU 0.2842554135884355 Accuracy 0.8480969323932163 CE Loss 0.5331596382613716
# Scores for datasets rotate by 340 degrees:
#    mIoU 0.2960183473182568 Accuracy 0.8494278133790862 CE Loss 0.5257449065299471
# Scores for datasets rotate by 350 degrees:
#    mIoU 0.3324745471401045 Accuracy 0.8553459911646781 CE Loss 0.49463580995085626
# VOC Dataset Val
# Using downloaded and verified file: /data/voc2012/VOCtrainval_11-May-2012.tar
# Using downloaded and verified file: /data/voc2012/VOCtrainval_11-May-2012.tar
# Using downloaded and verified file: /data/voc2012/VOCtrainval_11-May-2012.tar
# Using downloaded and verified file: /data/voc2012/VOCtrainval_11-May-2012.tar
# Using downloaded and verified file: /data/voc2012/VOCtrainval_11-May-2012.tar
# Using downloaded and verified file: /data/voc2012/VOCtrainval_11-May-2012.tar
# Scores for datasets rotate by 0 degrees:
#    mIoU 0.37717149273840633 Accuracy 0.8619365400949849 CE Loss 0.44270149171043877
# Scores for datasets rotate by 10 degrees:
#    mIoU 0.3255752705173852 Accuracy 0.8542211089263765 CE Loss 0.49480676898839476
# Scores for datasets rotate by 20 degrees:
#    mIoU 0.2952665903167009 Accuracy 0.8497780937475754 CE Loss 0.5214267817651757
# Scores for datasets rotate by 30 degrees:
#    mIoU 0.2827702115255165 Accuracy 0.848195682290582 CE Loss 0.5251363529891208
# Scores for datasets rotate by 330 degrees:
#    mIoU 0.2777787810202682 Accuracy 0.8469597605571686 CE Loss 0.5312839637570252
# Scores for datasets rotate by 340 degrees:
#    mIoU 0.286337186127318 Accuracy 0.8475405171287278 CE Loss 0.5265701300496064
# Scores for datasets rotate by 350 degrees:
#    mIoU 0.32281987851886135 Accuracy 0.853778442386302 CE Loss 0.49463682725840474
# EPOCH 1
# loss sup : 0.7982544898986816 loss unsup : 0.1987331360578537 loss : 0.49849382042884827 iou train : 0.45798439343846103
# EP: 1  combine loss train: 0.532894160062327  pixel accuracy between masks  0.9310420055594754
# EP: 1 iou: 0.45798439343846103 Accuracy: 0.8734533482589503 Loss CE 0.42091364494741496
# EPOCH 2
# EP: 2 iou: 0.4867497675703381 Accuracy: 0.8707585648743675 Loss CE 0.43244621235802716
# EPOCH 3
# loss sup : 0.43754667043685913 loss unsup : 0.16197283565998077 loss : 0.29975974559783936 iou train : 0.5002427256746896
# EP: 3  combine loss train: 0.4427307712672907  pixel accuracy between masks  0.924213699272238
# EP: 3 iou: 0.5002427256746896 Accuracy: 0.8818835015783176 Loss CE 0.3882610143886672
# Mean Pixel Accuracy between masks : 0.9285704524586819 Loss Validation : 0.2347902
# EPOCH 4
# loss sup : 0.6535101532936096 loss unsup : 0.118018239736557 loss : 0.3857641816139221 iou train : 0.4995412079851753
# EP: 4  combine loss train: 0.40932769704739774  pixel accuracy between masks  0.9289627736457354
# EP: 4 iou: 0.4995412079851753 Accuracy: 0.881946573029349 Loss CE 0.40413133932433104
# EPOCH 5
# loss sup : 0.5647768974304199 loss unsup : 0.16232308745384216 loss : 0.36355000734329224 iou train : 0.5112866259928909
# EP: 5  combine loss train: 0.3770737764149596  pixel accuracy between masks  0.9333511292888315
# EP: 5 iou: 0.5112866259928909 Accuracy: 0.8810690575218167 Loss CE 0.38594020020764314
# VOC Dataset Train
# Using downloaded and verified file: /data/voc2012/VOCtrainval_11-May-2012.tar
# Using downloaded and verified file: /data/voc2012/VOCtrainval_11-May-2012.tar
# Using downloaded and verified file: /data/voc2012/VOCtrainval_11-May-2012.tar
# Using downloaded and verified file: /data/voc2012/VOCtrainval_11-May-2012.tar
# Using downloaded and verified file: /data/voc2012/VOCtrainval_11-May-2012.tar
# Using downloaded and verified file: /data/voc2012/VOCtrainval_11-May-2012.tar
# Using downloaded and verified file: /data/voc2012/VOCtrainval_11-May-2012.tar
# Scores for datasets rotate by 0 degrees:
#    mIoU 0.5542880437090838 Accuracy 0.8920003758851489 CE Loss 0.35502651109375427
# Scores for datasets rotate by 10 degrees:
#    mIoU 0.5152815937861829 Accuracy 0.8877157323091474 CE Loss 0.38206278606791233
# Scores for datasets rotate by 20 degrees:
#    mIoU 0.4641529196217112 Accuracy 0.8787119517331134 CE Loss 0.4193556690156012
# Scores for datasets rotate by 30 degrees:
#    mIoU 0.450481385004222 Accuracy 0.8775251373193326 CE Loss 0.4246295743184215
# Scores for datasets rotate by 330 degrees:
#    mIoU 0.4352765562370897 Accuracy 0.8739374348263653 CE Loss 0.438329342829033
# Scores for datasets rotate by 340 degrees:
#    mIoU 0.452685356759786 Accuracy 0.8764017408938791 CE Loss 0.428625178963577
# Scores for datasets rotate by 350 degrees:
#    mIoU 0.5093498877399736 Accuracy 0.8866377098692081 CE Loss 0.3857311634270505
# VOC Dataset Val
# Using downloaded and verified file: /data/voc2012/VOCtrainval_11-May-2012.tar
# Using downloaded and verified file: /data/voc2012/VOCtrainval_11-May-2012.tar
# Using downloaded and verified file: /data/voc2012/VOCtrainval_11-May-2012.tar
# Using downloaded and verified file: /data/voc2012/VOCtrainval_11-May-2012.tar
# Using downloaded and verified file: /data/voc2012/VOCtrainval_11-May-2012.tar
# Using downloaded and verified file: /data/voc2012/VOCtrainval_11-May-2012.tar
# Using downloaded and verified file: /data/voc2012/VOCtrainval_11-May-2012.tar
# Scores for datasets rotate by 0 degrees:
#    mIoU 0.5112866259928909 Accuracy 0.8810690575218167 CE Loss 0.38594020026163284
# Scores for datasets rotate by 10 degrees:
#    mIoU 0.46858827165775535 Accuracy 0.8758500123529388 CE Loss 0.41826585476113814
# Scores for datasets rotate by 20 degrees:
#    mIoU 0.4247886982091884 Accuracy 0.8681036426876728 CE Loss 0.45461193132525973
# Scores for datasets rotate by 30 degrees:
#    mIoU 0.4128779776321118 Accuracy 0.8673460655379551 CE Loss 0.4561851555475126
# Scores for datasets rotate by 330 degrees:
#    mIoU 0.40605327012955666 Accuracy 0.8666795198484162 CE Loss 0.46322119495914343
# Scores for datasets rotate by 340 degrees:
#    mIoU 0.4174182050912834 Accuracy 0.8670911840853313 CE Loss 0.4601111392072145
# Scores for datasets rotate by 350 degrees:
#    mIoU 0.46780604037338364 Accuracy 0.8757303419824323 CE Loss 0.419163716540481
# EPOCH 6
# loss sup : 0.26962709426879883 loss unsup : 0.05085071176290512 loss : 0.16023890674114227 iou train : 0.4891533850665145
# EP: 6  combine loss train: 0.37395212696979097  pixel accuracy between masks  0.9283247099404202
# EP: 6 iou: 0.4891533850665145 Accuracy: 0.871196741988966 Loss CE 0.4504089786563765
# Mean Pixel Accuracy between masks : 0.9186785630483575 Loss Validation : 0.27095887
# EPOCH 7
# loss sup : 0.19952547550201416 loss unsup : 0.12029267102479935 loss : 0.15990906953811646 iou train : 0.5021092277614551
# EP: 7  combine loss train: 0.3439792393236259  pixel accuracy between masks  0.9297175144703146
# EP: 7 iou: 0.5021092277614551 Accuracy: 0.8745922407210033 Loss CE 0.4082844379988516
# EPOCH 8
# loss sup : 0.5522724986076355 loss unsup : 0.7324627637863159 loss : 0.6423676013946533 iou train : 0.4976028119749502
# EP: 8  combine loss train: 0.336479991271405  pixel accuracy between masks  0.9316713233805007
# EP: 8 iou: 0.4976028119749502 Accuracy: 0.8782161565209224 Loss CE 0.40339365327220444
# EPOCH 9
# loss sup : 0.05679614469408989 loss unsup : 0.19519056379795074 loss : 0.12599335610866547 iou train : 0.491878313964398
# EP: 9  combine loss train: 0.31064325407399734  pixel accuracy between masks  0.9350138435670795
# EP: 9 iou: 0.491878313964398 Accuracy: 0.879889354421127 Loss CE 0.39648572653994796
# Mean Pixel Accuracy between masks : 0.9229459319526628 Loss Validation : 0.26375043
# EPOCH 10
# loss sup : 0.3078354299068451 loss unsup : 0.3149853050708771 loss : 0.3114103674888611 iou train : 0.49784672324914103
# EP: 10  combine loss train: 0.3067116257738977  pixel accuracy between masks  0.9361470643716682
# EP: 10 iou: 0.49784672324914103 Accuracy: 0.8717516033297806 Loss CE 0.42863595099018065
# VOC Dataset Train
# Using downloaded and verified file: /data/voc2012/VOCtrainval_11-May-2012.tar
# Using downloaded and verified file: /data/voc2012/VOCtrainval_11-May-2012.tar
# Using downloaded and verified file: /data/voc2012/VOCtrainval_11-May-2012.tar
# Using downloaded and verified file: /data/voc2012/VOCtrainval_11-May-2012.tar
# Using downloaded and verified file: /data/voc2012/VOCtrainval_11-May-2012.tar
# Using downloaded and verified file: /data/voc2012/VOCtrainval_11-May-2012.tar
# Using downloaded and verified file: /data/voc2012/VOCtrainval_11-May-2012.tar
# Scores for datasets rotate by 0 degrees:
#    mIoU 0.5566742742976716 Accuracy 0.8888394924944224 CE Loss 0.37583672906185595
# Scores for datasets rotate by 10 degrees:
#    mIoU 0.5158813953452823 Accuracy 0.8823914202193875 CE Loss 0.40305731505094494
# Scores for datasets rotate by 20 degrees:
#    mIoU 0.46366814618501223 Accuracy 0.8718934254454037 CE Loss 0.4458307357062204
# Scores for datasets rotate by 30 degrees:
#    mIoU 0.44944291658044444 Accuracy 0.8689218714634461 CE Loss 0.45650296272262114
# Scores for datasets rotate by 330 degrees:
#    mIoU 0.44940394406203765 Accuracy 0.8684772887565881 CE Loss 0.461609305628153
# Scores for datasets rotate by 340 degrees:
#    mIoU 0.465717059860589 Accuracy 0.8717754712710577 CE Loss 0.44854224314709584
# Scores for datasets rotate by 350 degrees:
#    mIoU 0.5182514396309204 Accuracy 0.8829815902164775 CE Loss 0.40184013535080304
# VOC Dataset Val
# Using downloaded and verified file: /data/voc2012/VOCtrainval_11-May-2012.tar
# Using downloaded and verified file: /data/voc2012/VOCtrainval_11-May-2012.tar
# Using downloaded and verified file: /data/voc2012/VOCtrainval_11-May-2012.tar
# Using downloaded and verified file: /data/voc2012/VOCtrainval_11-May-2012.tar
# Using downloaded and verified file: /data/voc2012/VOCtrainval_11-May-2012.tar
# Using downloaded and verified file: /data/voc2012/VOCtrainval_11-May-2012.tar
# Using downloaded and verified file: /data/voc2012/VOCtrainval_11-May-2012.tar
# Scores for datasets rotate by 0 degrees:
#    mIoU 0.49784672324914103 Accuracy 0.8717516033297806 CE Loss 0.4286359498332582
# Scores for datasets rotate by 10 degrees:
#    mIoU 0.46151929335826575 Accuracy 0.8662828833188365 CE Loss 0.4575627059274044
# Scores for datasets rotate by 20 degrees:
#    mIoU 0.41596917829199753 Accuracy 0.857071873685586 CE Loss 0.5007785393569163
# Scores for datasets rotate by 30 degrees:
#    mIoU 0.4009396226483761 Accuracy 0.8542843181994519 CE Loss 0.5098778652252206
# Scores for datasets rotate by 330 degrees:
#    mIoU 0.4045188378773838 Accuracy 0.8556874282814918 CE Loss 0.5098740364572071
# Scores for datasets rotate by 340 degrees:
#    mIoU 0.4174100907833336 Accuracy 0.8577921470020132 CE Loss 0.5000059990208465
# Scores for datasets rotate by 350 degrees:
#    mIoU 0.46396048178870186 Accuracy 0.8674370204303314 CE Loss 0.45414179083528067
# EPOCH 11
# loss sup : 0.11827617883682251 loss unsup : 0.5861308574676514 loss : 0.35220351815223694 iou train : 0.4721704196756709
# EP: 11  combine loss train: 0.28766439744706773  pixel accuracy between masks  0.9366932677106199
# EP: 11 iou: 0.4721704196756709 Accuracy: 0.865387969054357 Loss CE 0.455385496626493
# EPOCH 12
# loss sup : 0.8745197057723999 loss unsup : 0.03829321265220642 loss : 0.45640647411346436 iou train : 0.48408908606250345
# EP: 12  combine loss train: 0.27331689905343703  pixel accuracy between masks  0.9372013782729697
# EP: 12 iou: 0.48408908606250345 Accuracy: 0.8749002831987782 Loss CE 0.42226844361685656
# Mean Pixel Accuracy between masks : 0.924540700877372 Loss Validation : 0.24560496
# EPOCH 13
# loss sup : 0.5045118927955627 loss unsup : 0.21983246505260468 loss : 0.3621721863746643 iou train : 0.47872517302899614
# EP: 13  combine loss train: 0.259323976580001  pixel accuracy between masks  0.9378705078329153
# EP: 13 iou: 0.47872517302899614 Accuracy: 0.8667440307741311 Loss CE 0.48370777504496776
# EPOCH 14
# loss sup : 0.280038058757782 loss unsup : 0.22809530794620514 loss : 0.25406667590141296 iou train : 0.4454663725284968
# EP: 14  combine loss train: 0.24932574348652128  pixel accuracy between masks  0.939934871335058
# EP: 14 iou: 0.4454663725284968 Accuracy: 0.8532392927585235 Loss CE 0.5173038863123821
# EPOCH 15
# loss sup : 1.6229058504104614 loss unsup : 0.3544420301914215 loss : 0.9886739253997803 iou train : 0.5035175129967455
# EP: 15  combine loss train: 0.24170336243981252  pixel accuracy between masks  0.9408169092812533
# EP: 15 iou: 0.5035175129967455 Accuracy: 0.8815752625765167 Loss CE 0.4214108521523683
# Mean Pixel Accuracy between masks : 0.9232987119975515 Loss Validation : 0.24637634
# VOC Dataset Train
# Using downloaded and verified file: /data/voc2012/VOCtrainval_11-May-2012.tar
# Using downloaded and verified file: /data/voc2012/VOCtrainval_11-May-2012.tar
# Using downloaded and verified file: /data/voc2012/VOCtrainval_11-May-2012.tar
# Using downloaded and verified file: /data/voc2012/VOCtrainval_11-May-2012.tar
# Using downloaded and verified file: /data/voc2012/VOCtrainval_11-May-2012.tar
# Using downloaded and verified file: /data/voc2012/VOCtrainval_11-May-2012.tar
# Using downloaded and verified file: /data/voc2012/VOCtrainval_11-May-2012.tar
# Scores for datasets rotate by 0 degrees:
#    mIoU 0.5829659111032273 Accuracy 0.8999231683682543 CE Loss 0.36378751016257566
# Scores for datasets rotate by 10 degrees:
#    mIoU 0.5226040735262681 Accuracy 0.8884457325920716 CE Loss 0.4249709177395848
# Scores for datasets rotate by 20 degrees:
#    mIoU 0.4738467666095841 Accuracy 0.8792988352612604 CE Loss 0.45957009992282327
# Scores for datasets rotate by 30 degrees:
#    mIoU 0.46587954219558253 Accuracy 0.8793709102281179 CE Loss 0.45718178826211214
# Scores for datasets rotate by 330 degrees:
#    mIoU 0.47451692613764296 Accuracy 0.8810231780685162 CE Loss 0.4529945857331788
# Scores for datasets rotate by 340 degrees:
#    mIoU 0.4802732038789318 Accuracy 0.8807884165737058 CE Loss 0.45793407956326554
# Scores for datasets rotate by 350 degrees:
#    mIoU 0.5263871030647069 Accuracy 0.8896896522456106 CE Loss 0.41895864732421
# VOC Dataset Val
# Using downloaded and verified file: /data/voc2012/VOCtrainval_11-May-2012.tar
# Using downloaded and verified file: /data/voc2012/VOCtrainval_11-May-2012.tar
# Using downloaded and verified file: /data/voc2012/VOCtrainval_11-May-2012.tar
# Using downloaded and verified file: /data/voc2012/VOCtrainval_11-May-2012.tar
# Using downloaded and verified file: /data/voc2012/VOCtrainval_11-May-2012.tar
# Using downloaded and verified file: /data/voc2012/VOCtrainval_11-May-2012.tar
# Using downloaded and verified file: /data/voc2012/VOCtrainval_11-May-2012.tar
# Scores for datasets rotate by 0 degrees:
#    mIoU 0.5035175129967455 Accuracy 0.8815752625765167 CE Loss 0.42141085171016684
# Scores for datasets rotate by 10 degrees:
#    mIoU 0.4483223043575453 Accuracy 0.871637144674352 CE Loss 0.48790302643330036
# Scores for datasets rotate by 20 degrees:
#    mIoU 0.4108052767221158 Accuracy 0.8643684509006415 CE Loss 0.5222034062213265
# Scores for datasets rotate by 30 degrees:
#    mIoU 0.40403509446979124 Accuracy 0.8646222374336923 CE Loss 0.5145650359476082
# Scores for datasets rotate by 330 degrees:
#    mIoU 0.4047921002657708 Accuracy 0.8652091857881992 CE Loss 0.5076188724128089
# Scores for datasets rotate by 340 degrees:
#    mIoU 0.40755040831668543 Accuracy 0.864181428938954 CE Loss 0.5192854677110376
# Scores for datasets rotate by 350 degrees:
#    mIoU 0.4473402894317027 Accuracy 0.8712150467982408 CE Loss 0.4851637361114851
# EPOCH 16
# loss sup : 0.1494203507900238 loss unsup : 0.09898786246776581 loss : 0.1242041066288948 iou train : 0.5163612882412844
# EP: 16  combine loss train: 0.2298804060718078  pixel accuracy between masks  0.9421169612992578
# loss sup : 0.2021981179714203 loss unsup : 0.08373436331748962 loss : 0.14296624064445496 iou train : 0.4558363834321281
# EP: 17  combine loss train: 0.22675615177609845  pixel accuracy between masks  0.9405576930300773
# EP: 17 iou: 0.4558363834321281 Accuracy: 0.8622065436885671 Loss CE 0.4727688436316078
# EPOCH 18
# loss sup : 0.12766426801681519 loss unsup : 0.1175350546836853 loss : 0.12259966135025024 iou train : 0.4792177823242745
# EP: 18  combine loss train: 0.21883114322543368  pixel accuracy between masks  0.9435582356668757
# EP: 18 iou: 0.4792177823242745 Accuracy: 0.8750199203899036 Loss CE 0.42918120336695076
# Mean Pixel Accuracy between masks : 0.9094027519893899 Loss Validation : 0.2943913
# EPOCH 19
# loss sup : 0.2936634123325348 loss unsup : 0.04064495489001274 loss : 0.16715417802333832 iou train : 0.4381126323226183
# EP: 19  combine loss train: 0.2134549446361926  pixel accuracy between masks  0.9450930097437806
# EP: 19 iou: 0.4381126323226183 Accuracy: 0.8606287135384125 Loss CE 0.5597068961154416
# EPOCH 20
# loss sup : 0.2771603763103485 loss unsup : 0.29247617721557617 loss : 0.28481829166412354 iou train : 0.4800873716963132
# EP: 20  combine loss train: 0.20994869676030478  pixel accuracy between masks  0.9450656410872007
# Using downloaded and verified file: /data/voc2012/VOCtrainval_11-May-2012.tar
# Using downloaded and verified file: /data/voc2012/VOCtrainval_11-May-2012.tar
# Using downloaded and verified file: /data/voc2012/VOCtrainval_11-May-2012.tar
# Using downloaded and verified file: /data/voc2012/VOCtrainval_11-May-2012.tar
# Using downloaded and verified file: /data/voc2012/VOCtrainval_11-May-2012.tar
# Using downloaded and verified file: /data/voc2012/VOCtrainval_11-May-2012.tar
# Using downloaded and verified file: /data/voc2012/VOCtrainval_11-May-2012.tar
# Scores for datasets rotate by 0 degrees:
#    mIoU 0.5752002030080835 Accuracy 0.8973647318685938 CE Loss 0.37686525007119515
# Scores for datasets rotate by 10 degrees:
#    mIoU 0.5142428891833646 Accuracy 0.8859367825847965 CE Loss 0.43121223551567256
# Scores for datasets rotate by 20 degrees:
#    mIoU 0.4625372126065164 Accuracy 0.8761461011009797 CE Loss 0.47619166421383374
# Scores for datasets rotate by 30 degrees:
#    mIoU 0.44860149724770854 Accuracy 0.8748032438282084 CE Loss 0.47473752914159434
# Scores for datasets rotate by 330 degrees:
#    mIoU 0.45565110400771786 Accuracy 0.8762763195387525 CE Loss 0.47366621960310745
# Scores for datasets rotate by 340 degrees:
#    mIoU 0.4680982705239175 Accuracy 0.8772135416666667 CE Loss 0.4783627430760795
# Scores for datasets rotate by 350 degrees:
#    mIoU 0.519392487135433 Accuracy 0.8869008724173053 CE Loss 0.43010005165817716
# VOC Dataset Val
# Using downloaded and verified file: /data/voc2012/VOCtrainval_11-May-2012.tar
# Using downloaded and verified file: /data/voc2012/VOCtrainval_11-May-2012.tar
# Using downloaded and verified file: /data/voc2012/VOCtrainval_11-May-2012.tar
# Using downloaded and verified file: /data/voc2012/VOCtrainval_11-May-2012.tar
# Using downloaded and verified file: /data/voc2012/VOCtrainval_11-May-2012.tar
# Using downloaded and verified file: /data/voc2012/VOCtrainval_11-May-2012.tar
# Using downloaded and verified file: /data/voc2012/VOCtrainval_11-May-2012.tar
# Scores for datasets rotate by 0 degrees:
#    mIoU 0.4800873716963132 Accuracy 0.874180339123901 CE Loss 0.45697106277278327
# Scores for datasets rotate by 10 degrees:
#    mIoU 0.4235894904473233 Accuracy 0.8642195061070479 CE Loss 0.5192976215194841
# Scores for datasets rotate by 20 degrees:
#    mIoU 0.38434884187942553 Accuracy 0.8572479668696223 CE Loss 0.5649790512031526
# Scores for datasets rotate by 30 degrees:
#    mIoU 0.38040389801298913 Accuracy 0.8584125248590132 CE Loss 0.5578288896249709
# Scores for datasets rotate by 330 degrees:
#    mIoU 0.3817421888451045 Accuracy 0.858956505915118 CE Loss 0.5470708126357767
# Scores for datasets rotate by 340 degrees:
#    mIoU 0.38977502645260564 Accuracy 0.8588183878087724 CE Loss 0.5550438355142862
# Scores for datasets rotate by 350 degrees:
#    mIoU 0.42751121044929946 Accuracy 0.865268380356173 CE Loss 0.5140761212812797
# EPOCH 21
# AttributeErrorTraceback (most recent call last)
# <ipython-input-16-c490c1257bed> in <module>
#      19         loss_equiv,acc = compute_transformations_batch(x_unsup,model,angle,reshape=False,\
#      20                                                      criterion=criterion_unsupervised,Loss = Loss,\
# ---> 21                                                        device=device)
#      22         x,mask = batch_sup
#      23         x = x.to(device)
#
# /workspace/utils.py in compute_transformations_batch(x, model, angle, reshape, criterion, Loss, device, plot)
#     262         pred_x = model(x.to(device))
#     263         pred_rot = model(rot_x.to(device))
# --> 264     pred_rot_x = rotate_mask(pred_x.detach().cpu(),angle,reshape=reshape) # Apply the rotation on the mask with the original input
#     265     if Loss=='KL':
#     266         loss = criterion(logsoftmax(pred_rot_x.cpu()),softmax(pred_rot.cpu())) #KL divergence between the two predictions
#
# AttributeError: 'collections.OrderedDict' object has no attribute 'detach'

# %%
model.eval()
print("EVAL ON TRAIN VOC 2012:")
m_pix_acc, m_loss_equiv = eval_accuracy_equiv(model,dataloader_train_VOC,criterion=criterion_unsupervised,\
                        nclass=21,device=device,Loss=Loss,plot=False,angle_max=30,random_angle=False) 
d_iou = ev.eval_model_all_angle(model,train=True,batch_size=batch_size,device=device,num_classes=21)
print("EVAL ON VAL VOC 2012:")
m_pix_acc, m_loss_equiv = eval_accuracy_equiv(model,dataloader_val,criterion=criterion_unsupervised,\
                        nclass=21,device=device,Loss=Loss,plot=False,angle_max=30,random_angle=False) 
d_iou = ev.eval_model_all_angle(model,train=False,batch_size=batch_size,device=device,num_classes=21)

# %% [markdown]
# ## Plot

# %%
plt.figure(figsize=(10,8))
plt.subplot(2,1,1)
plt.title("FCN CE semisup. Combine loss train")
plt.plot(combine_loss_train)
plt.xlabel("iterations")
plt.ylabel("Loss")

plt.figure(figsize=(10,8))
plt.subplot(2,1,1)
plt.title("FCN CE semisup. Equivariance loss train")
plt.plot(loss_train_unsup)
plt.xlabel("iterations")
plt.ylabel("Loss")

plt.figure(figsize=(10,8))
plt.subplot(2,1,1)
plt.title("FCN CE semisup. CE loss train")
plt.plot(loss_train_sup)
plt.xlabel("iterations")
plt.ylabel("Loss")

plt.figure(figsize=(10,8))
plt.subplot(2,1,1)
plt.title("FCN CE semisup. Equivariance Accuracy train")
plt.plot(pix_accuracy_train)
plt.xlabel("iterations")
plt.ylabel("Accuracy")

plt.figure(figsize=(10,8))
plt.subplot(2,1,1)
plt.title("FCN CE semisup. Mean iou train ")
plt.plot(iou_train)
plt.xlabel("iterations")
plt.ylabel("Mean IOU")

plt.figure(figsize=(10,8))
plt.subplot(2,1,1)
plt.title("FCN CE semisup. Cross entropy loss test")
plt.plot(loss_test)
plt.xlabel("iterations")
plt.ylabel("Loss")

plt.figure(figsize=(10,8))
plt.subplot(2,1,1)
plt.title("FCN CE semisup. Equivariance loss test")
plt.plot(loss_test_unsup)
plt.xlabel("iterations")
plt.ylabel("Loss")

plt.figure(figsize=(10,8))
plt.subplot(2,1,1)
plt.title("FCN CE semisup. Equivariance accuracy test")
plt.plot(pix_accuracy_test)
plt.xlabel("iterations")
plt.ylabel("Loss")


plt.figure(figsize=(10,8))
plt.subplot(2,1,1)
plt.title("FCN CE  semisup. Mean iou test")
plt.plot(iou_test)
plt.xlabel("iterations")
plt.ylabel("Mean IOU")
# Out:
# Text(0, 0.5, 'Mean IOU')
